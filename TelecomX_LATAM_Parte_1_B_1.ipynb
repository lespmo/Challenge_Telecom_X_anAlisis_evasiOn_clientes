# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ##📌 Leyendo Archivo de formato JSON

# %%
# IMPORTANTO LA BIBILIOTECA PANDAS
import pandas as pd

# %%
# LEYENDO DATOS DESDE MI GITHUB
url_TelecomX_Data = 'https://github.com/lespmo/Challenge_Telecom_X_anAlisis_evasiOn_clientes/blob/d2cf422f1741ff3547e2c812955f21ea1ff12d85/TelecomX_Data.json'

# %%
# LEYENDO LOS DATOS DESDE COLAB
df_TelecomX_Data_Colab = pd.read_json('/content/TelecomX_Data.json')
#df_TelecomX_Data_GiHub = pd.read_json('url_TelecomX_Data')

# %% [markdown]
# ##📌 Revisando los datos

# %%
df_TelecomX_Data_Colab
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df_TelecomX_Data_Colab.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_TelecomX_Data_Colab.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_TelecomX_Data_Colab.shape
# Out:
# (7267, 6)

# %%
df_TelecomX_Data_Colab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_TelecomX_Data_Colab.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_TelecomX_Data_Colab['customer']
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %%
df_TelecomX_Data_Colab.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %% [markdown]
# ### Observaciones de la revision
# - Existen columnas con listas y diccionarios anidados
# - Las columnas con anidados son [ customer, phone, 	internet, 	account]
# - La columna ['customerID'] es variable numerica
# - Las columnas ['customerID', 'Churn'] es variable categorica
# - Todos las columnas del data frame son de tipo object
# - Se deben normalizar los datos

# %% [markdown]
# ### Observaciones de la revision
# 1. Existen columnas con listas y diccionarios anidados
# 2. Las columnas con anidados son [ customer, phone, 	internet, 	account]
# 3. La columna ['customerID'] es variable numerica
# 4. Las columnas ['customerID', 'Churn'] es variable categorica
# 5. Todos las columnas del data frame son de tipo object
# 6. Se deben normalizar los datos

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##🔧 Importando Bibliotecas

# %%
import json

# %%
import requests

# %% [markdown]
# ##🔧 Normalizando metodo 1

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('TelecomX_Data.json','r') as f:
    df_TelecomX_Data_Colab_2 = json.loads(f.read())

# %%
df_TelecomX_Data_Colab_2
# Out:
# [{'customerID': '0002-ORFBO',
#   'Churn': 'No',
#   'customer': {'gender': 'Female',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'No',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'No'},
#   'account': {'Contract': 'One year',
#    'PaperlessBilling': 'Yes',
#    'PaymentMethod': 'Mailed check',
#    'Charges': {'Monthly': 65.6, 'Total': '593.3'}}},
#  {'customerID': '0003-MKNFE',
#   'Churn': 'No',
#   'customer': {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'No',
#    'Dependents': 'No',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'No',
#    'DeviceProtection': 'No',
# ...

# %%
type(df_TelecomX_Data_Colab_2)
# Out:
# list

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_TelecomX_Data_Colab_2_norm = pd.json_normalize(df_TelecomX_Data_Colab_2)

# %%
df_TelecomX_Data_Colab_2_norm.sample(5)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 4677  6407-GSJNL    No          Female                       0
# 5981  8174-TBVCF    No          Female                       0
# 1854  2637-FKFSY    No          Female                       0
# 428   0617-AQNWT   Yes          Female                       0
# 2900  4018-KJYUY    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 4677               No                  No               51                Yes
# 5981              Yes                  No               70                Yes
# 1854              Yes                  No                3                Yes
# 428               Yes                  No               64                 No
# 2900               No                 Yes               22                Yes
#
#      phone.MultipleLines internet.InternetService  ... internet.OnlineBackup  \
# ...

# %%
df_TelecomX_Data_Colab_2_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=0)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=1)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=2)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_TelecomX_Normalizado_1 = pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=2)

# %%
df_TelecomX_Normalizado_1
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_TelecomX_Normalizado_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %% [markdown]
# ##🔧 Normalizando metodo 2

# %%
pd.json_normalize(df_TelecomX_Data_Colab)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df_TelecomX_Data_Colab.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 657   0932-YIXYU    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 118   0201-MIBOL    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 1693  2400-FEQME    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2040  2876-VBBBL   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2156  3014-WJKSM    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 657    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 118   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1693   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2040   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2156   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 657   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 118   {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# pd.json_normalize(datos_pacientes_2_metodo, record_path='Pacientes', meta=['Investigación', 'Año'])
pd.json_normalize(df_TelecomX_Data_Colab['customer'])
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
pd.json_normalize(df_TelecomX_Data_Colab['phone'])
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
pd.json_normalize(df_TelecomX_Data_Colab['internet'])
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab['account'])
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %% [markdown]
# ###🔧 Creando un DF de cada lista anidada

# %%
df_TelecomX_Data_Colab.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_customer_details = pd.json_normalize(df_TelecomX_Data_Colab['customer'])

# %%
df_phone_details = pd.json_normalize(df_TelecomX_Data_Colab['phone'])

# %%
df_internet_details = pd.json_normalize(df_TelecomX_Data_Colab['internet'])

# %%
df_account_details = pd.json_normalize(df_TelecomX_Data_Colab['account'])

# %% [markdown]
# ###🔧 Uniendo los data frame

# %%
df_customer = pd.DataFrame()

# %%
df_customer_details
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_TelecomX_Data_Colab[['customerID', 'Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %%
df_base = df_TelecomX_Data_Colab[['customerID', 'Churn']]

# %%
pd.merge(df_base, df_customer_details, left_index=True, right_index=True)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
# [7267 rows x 7 columns]

# %%
df_TelecomX_Normalizado = pd.merge(df_base, df_customer_details, left_index=True, right_index=True)

# %%
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
# [7267 rows x 7 columns]

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_phone_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines
# 0             Yes                No
# ...

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_internet_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# ...

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_account_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_TelecomX_Normalizado.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado.shape
# Out:
# (7267, 21)

# %% [markdown]
# ##🔧 Normalizando metodo 3

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('TelecomX_Data.json','r') as f:
    df_TelecomX_Data_Colab_3 = json.loads(f.read())

# %%
df_TelecomX_Data_Colab_3
# Out:
# [{'customerID': '0002-ORFBO',
#   'Churn': 'No',
#   'customer': {'gender': 'Female',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'No',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'No'},
#   'account': {'Contract': 'One year',
#    'PaperlessBilling': 'Yes',
#    'PaymentMethod': 'Mailed check',
#    'Charges': {'Monthly': 65.6, 'Total': '593.3'}}},
#  {'customerID': '0003-MKNFE',
#   'Churn': 'No',
#   'customer': {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'No',
#    'Dependents': 'No',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'No',
#    'DeviceProtection': 'No',
# ...

# %%
type(df_TelecomX_Data_Colab_3)
# Out:
# list

# %%
#pd.json_normalize(df_TelecomX_Data_Colab_3, record_path=['customer', 'phone', 'internet', 'account'], meta=['customerID', 'Churn'])
# eror se tiene diccionarios anidados con llaves,  pero no como listas de registros, record_path sirve cuando dentro de un diccionario tienes una lista de diccionarios que se quiere expandir en filas.

pd.json_normalize(
    df_TelecomX_Data_Colab_3,
    sep="_"  # separador para las claves anidadas
)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_TelecomX_Normalizado_2 = pd.json_normalize(
    df_TelecomX_Data_Colab_3,
    sep="_"  # separador para las claves anidadas
)

# %%
df_TelecomX_Normalizado_2.sample(5)
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 992   1395-QOUWC                Female                       0
# 5057  6907-FLBER    No            Male                       0
# 5635  7694-VLBWQ   Yes            Male                       0
# 427   0616-ATFGB   Yes            Male                       1
# 5260  7175-NTIXE    No          Female                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 992               Yes                 Yes               22                Yes
# 5057               No                  No                1                Yes
# 5635              Yes                  No               67                Yes
# 427               Yes                  No                1                 No
# 5260               No                  No               25                Yes
#
#      phone_MultipleLines internet_InternetService  ... internet_OnlineBackup  \
# ...

# %%
df_TelecomX_Normalizado_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %% [markdown]
# ##🔧 Guardando Archivos Json

# %%
df_TelecomX_Normalizado.to_json('TelecomX_Normalizado.json')

# %%
df_TelecomX_Normalizado_1.to_json('TelecomX_Normalizado_1.json')

# %%
df_TelecomX_Normalizado_2.to_json('TelecomX_Normalizado_2.json')

# %% [markdown]
# ##🔧Revisando Datos e inconsistencias

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_TelecomX_Normalizado.tail()
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 7262          Yes                No             DSL  ...           No
# 7263          Yes               Yes     Fiber optic  ...           No
# 7264          Yes                No             DSL  ...          Yes
# 7265          Yes                No             DSL  ...           No
# 7266           No  No phone service             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_TelecomX_Normalizado.shape
# Out:
# (7267, 21)

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
df_TelecomX_Normalizado.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly
# count    7267.000000  7267.000000      7267.000000
# mean        0.162653    32.346498        64.720098
# std         0.369074    24.571773        30.129572
# min         0.000000     0.000000        18.250000
# 25%         0.000000     9.000000        35.425000
# 50%         0.000000    29.000000        70.300000
# 75%         0.000000    55.000000        89.875000
# max         1.000000    72.000000       118.750000

# %%
df_TelecomX_Normalizado.groupby('InternetService').mean(numeric_only=True)
# Out:
#                  SeniorCitizen     tenure  Charges.Monthly
# InternetService
# DSL                   0.107315  32.701367        58.009144
# Fiber optic           0.268918  32.923390        91.514478
# No                    0.034788  30.621126        21.082163

# %%
df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean()
# Out:
# InternetService
# DSL            58.009144
# Fiber optic    91.514478
# No             21.082163
# Name: Charges.Monthly, dtype: float64

# %%
#df_TelecomX_Normalizado.groupby('InternetService')['Charges.T#otal'].mean()

# %%
# df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean().sort_values('Charges.Monthly')

# %%
df_TelecomX_Normalizado.groupby('InternetService').sum(numeric_only=True)
# Out:
#                  SeniorCitizen  tenure  Charges.Monthly
# InternetService
# DSL                        267   81361        144326.75
# Fiber optic                860  105289        292663.30
# No                          55   48412         33330.90

# %%
df_TelecomX_Normalizado.groupby(['InternetService', 'gender'])[['Charges.Monthly']].sum()
# Out:
#                         Charges.Monthly
# InternetService gender
# DSL             Female         71445.45
#                 Male           72881.30
# Fiber optic     Female        146253.35
#                 Male          146409.95
# No              Female         16296.10
#                 Male           17034.80

# %%
df_TelecomX_Normalizado.groupby(['InternetService', 'gender'])[['Charges.Monthly']].mean()
# Out:
#                         Charges.Monthly
# InternetService gender
# DSL             Female        58.465998
#                 Male          57.568167
# Fiber optic     Female        91.522747
#                 Male          91.506219
# No              Female        21.108938
#                 Male          21.056613

# %%
df_TelecomX_Normalizado.InternetService.unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
InternetService_ = ['DSL', 'Fiber optic', 'No']
InternetService_
# Out:
# ['DSL', 'Fiber optic', 'No']

# %%
df_TelecomX_Normalizado.query('@InternetService_  in InternetService')
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.customerID.unique()
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9992-UJOEL',
#        '9993-LHIEB', '9995-HOTOH'], dtype=object)

# %%
df_TelecomX_Normalizado.Churn.unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df_TelecomX_Normalizado.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_TelecomX_Normalizado.SeniorCitizen.unique()
# Out:
# array([0, 1])

# %%
df_TelecomX_Normalizado.Partner.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_TelecomX_Normalizado.SeniorCitizen.unique()
# Out:
# array([0, 1])

# %%
df_TelecomX_Normalizado.tenure.unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %%
df_TelecomX_Normalizado.PhoneService.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_TelecomX_Normalizado.MultipleLines.unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
df_TelecomX_Normalizado.InternetService.unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df_TelecomX_Normalizado.OnlineSecurity.unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.OnlineBackup.unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.DeviceProtection.unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.TechSupport.unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.StreamingTV.unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.StreamingMovies.unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df_TelecomX_Normalizado.Contract.unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
df_TelecomX_Normalizado.PaperlessBilling.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_TelecomX_Normalizado.PaymentMethod.unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
#df_TelecomX_Normalizado.Charges.Monthly.unique() genera error
df_TelecomX_Normalizado['Charges.Monthly'].unique()
# Out:
# array([65.6 , 59.9 , 73.9 , ..., 91.75, 68.8 , 67.85])

# %%
df_TelecomX_Normalizado['Charges.Total'].unique()
# Out:
# array(['593.3', '542.4', '280.85', ..., '742.9', '4627.65', '3707.6'],
#       dtype=object)

# %%
reporte_unique = {
    "columna": [],
    "tipo_dato": [],
    "n_valores_unicos": [],
    "valores": []
}

for col in df_TelecomX_Normalizado.columns:
    reporte_unique["columna"].append(col)
    reporte_unique["tipo_dato"].append(df_TelecomX_Normalizado[col].dtype)   # 👈 tipo de dato
    reporte_unique["n_valores_unicos"].append(df_TelecomX_Normalizado[col].nunique())
    reporte_unique["valores"].append(df_TelecomX_Normalizado[col].unique())
    #reporte_unique["tipo de dato"].append(df_TelecomX_Normalizado[col].dtype())

df_reporte_unique = pd.DataFrame(reporte_unique)

# %%
df_reporte_unique
# Out:
#              columna tipo_dato  n_valores_unicos  \
# 0         customerID    object              7267
# 1              Churn    object                 3
# 2             gender    object                 2
# 3      SeniorCitizen     int64                 2
# 4            Partner    object                 2
# 5         Dependents    object                 2
# 6             tenure     int64                73
# 7       PhoneService    object                 2
# 8      MultipleLines    object                 3
# 9    InternetService    object                 3
# 10    OnlineSecurity    object                 3
# 11      OnlineBackup    object                 3
# 12  DeviceProtection    object                 3
# 13       TechSupport    object                 3
# 14       StreamingTV    object                 3
# 15   StreamingMovies    object                 3
# 16          Contract    object                 3
# 17  PaperlessBilling    object                 2
# ...

# %%
print(df_reporte_unique)
# Out:
#              columna tipo_dato  n_valores_unicos  \
# 0         customerID    object              7267
# 1              Churn    object                 3
# 2             gender    object                 2
# 3      SeniorCitizen     int64                 2
# 4            Partner    object                 2
# 5         Dependents    object                 2
# 6             tenure     int64                73
# 7       PhoneService    object                 2
# 8      MultipleLines    object                 3
# 9    InternetService    object                 3
# 10    OnlineSecurity    object                 3
# 11      OnlineBackup    object                 3
# 12  DeviceProtection    object                 3
# 13       TechSupport    object                 3
# 14       StreamingTV    object                 3
# 15   StreamingMovies    object                 3
# 16          Contract    object                 3
# 17  PaperlessBilling    object                 2
# ...

# %%
import pandas as pd
# funcion de informe unquie y tip de datos
def reporte_unique(df):
    reporte = {
        "columna": [],
        "tipo_dato": [],
        "n_valores_unicos": [],
        "valores": []
    }

    for col in df.columns:
        reporte["columna"].append(col)
        reporte["tipo_dato"].append(df[col].dtype)
        reporte["n_valores_unicos"].append(df[col].nunique())
        reporte["valores"].append(df[col].unique())

    return pd.DataFrame(reporte)

# %%
# Ejemplo de uso:
df_reporte_unique_1 = reporte_unique(df_TelecomX_Normalizado)
df_reporte_unique_1
# Out:
#              columna tipo_dato  n_valores_unicos  \
# 0         customerID    object              7267
# 1              Churn    object                 3
# 2             gender    object                 2
# 3      SeniorCitizen     int64                 2
# 4            Partner    object                 2
# 5         Dependents    object                 2
# 6             tenure     int64                73
# 7       PhoneService    object                 2
# 8      MultipleLines    object                 3
# 9    InternetService    object                 3
# 10    OnlineSecurity    object                 3
# 11      OnlineBackup    object                 3
# 12  DeviceProtection    object                 3
# 13       TechSupport    object                 3
# 14       StreamingTV    object                 3
# 15   StreamingMovies    object                 3
# 16          Contract    object                 3
# 17  PaperlessBilling    object                 2
# ...

# %%
print(df_reporte_unique_1)
# Out:
#              columna tipo_dato  n_valores_unicos  \
# 0         customerID    object              7267
# 1              Churn    object                 3
# 2             gender    object                 2
# 3      SeniorCitizen     int64                 2
# 4            Partner    object                 2
# 5         Dependents    object                 2
# 6             tenure     int64                73
# 7       PhoneService    object                 2
# 8      MultipleLines    object                 3
# 9    InternetService    object                 3
# 10    OnlineSecurity    object                 3
# 11      OnlineBackup    object                 3
# 12  DeviceProtection    object                 3
# 13       TechSupport    object                 3
# 14       StreamingTV    object                 3
# 15   StreamingMovies    object                 3
# 16          Contract    object                 3
# 17  PaperlessBilling    object                 2
# ...

# %%
df_TelecomX_Normalizado.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_TelecomX_Normalizado.isnull()
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False  False   False          False    False       False   False
# 1          False  False   False          False    False       False   False
# 2          False  False   False          False    False       False   False
# 3          False  False   False          False    False       False   False
# 4          False  False   False          False    False       False   False
# ...          ...    ...     ...            ...      ...         ...     ...
# 7262       False  False   False          False    False       False   False
# 7263       False  False   False          False    False       False   False
# 7264       False  False   False          False    False       False   False
# 7265       False  False   False          False    False       False   False
# 7266       False  False   False          False    False       False   False
#
# ...

# %% [markdown]
# ##🔧 Limpiando y dando formato

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
# cambiar los nombres de las columnas que tienen como separador .
#df = df.rename(columns={'Edad': 'Años'})
df_TelecomX_Normalizado = df_TelecomX_Normalizado.rename(columns={'Charges.Monthly': 'Charges.Monthly'})

# %%
df_TelecomX_Normalizado = df_TelecomX_Normalizado.rename(columns={'Charges.Total': 'Charges.Total'})

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# ###🔧 Administrando tipos de datos

# %%
import numpy as np

# %%
df_TelecomX_Normalizado.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 104   0178-CIIKR    No  Female              0      No         No       3
# 801   1134-YWTYF    No    Male              0     Yes         No      27
# 5928  8096-LOIST    No  Female              0      No         No      19
# 3823  5231-FIQPA    No  Female              0      No         No      41
# 3255  4544-RXFMG    No    Male              0     Yes        Yes       8
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 104           Yes            No              No  ...  No internet service
# 801           Yes            No             DSL  ...                  Yes
# 5928          Yes            No             DSL  ...                   No
# 3823          Yes            No              No  ...  No internet service
# 3255          Yes            No             DSL  ...                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# gender	object	2	[Female, Male]

# %%
df_TelecomX_Normalizado['gender'] = df_TelecomX_Normalizado['gender'].astype(str).str.strip().str.lower()
#df_TelecomX_Normalizado['gender'].astype(str).str.lower()

# %% [markdown]
# Partner	object	2	[Yes, No]

# %%
#df_TelecomX_Normalizado["Partner"] = df_TelecomX_Normalizado["Partner"].astype(str).str.strip().str.lower().map({'yes':1, 'no':0, '':0}).astype(np.int64)
#df_TelecomX_Normalizado["Partner"] = df_TelecomX_Normalizado["Partner"].astype(str).str.strip().str.lower().astype(np.int64)
#df_TelecomX_Normalizado['Partner'].astype(str).str.strip().str.lower().str.astype(np.int64)
#df_TelecomX_Normalizado['Partner'] = df_TelecomX_Normalizado['Partner'].apply(lambda x: x.replace('$ ', '').replace(' reais', '').replace(',','.').strip())
#df_TelecomX_Normalizado["Dependents"] = df_TelecomX_Normalizado["Dependents"].astype(str).str.strip().str.lower().map({'yes':1, 'no':0, '':0}).astype(np.int64)
df_TelecomX_Normalizado["Partner"] = df_TelecomX_Normalizado["Partner"].astype(str).str.strip().str.lower()

# %% [markdown]
# Dependents	object	2	[Yes, No]

# %%
df_TelecomX_Normalizado["Dependents"] = df_TelecomX_Normalizado["Dependents"].astype(str).str.strip().str.lower()

# %% [markdown]
# PhoneService	object	2	[Yes, No]

# %%
df_TelecomX_Normalizado['PhoneService'] = df_TelecomX_Normalizado['PhoneService'].astype(str).str.strip().str.lower()

# %% [markdown]
# 8	MultipleLines	object	3	[No, Yes, No phone service]

# %%
df_TelecomX_Normalizado['MultipleLines'] = df_TelecomX_Normalizado['MultipleLines'].astype(str).str.strip().str.lower()

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
colms    =    ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                    'TechSupport', 'StreamingTV', 'StreamingMovies'
                    ]
for c in colms:
     df_TelecomX_Normalizado[c] = df_TelecomX_Normalizado[c].astype(str).str.strip()

# %%
colms    =    ['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                    'TechSupport', 'StreamingTV', 'StreamingMovies'
                    ]
for c in colms:
     df_TelecomX_Normalizado[c] = df_TelecomX_Normalizado[c].str.lower()

# %%
colms =   ['Contract', 'PaperlessBilling', 'PaymentMethod']
for c in colms:
     df_TelecomX_Normalizado[c] = df_TelecomX_Normalizado[c].astype(str).str.strip()

# %%
colms =   ['Contract', 'PaperlessBilling', 'PaymentMethod']
for c in colms:
     df_TelecomX_Normalizado[c] = df_TelecomX_Normalizado[c].str.lower()

# %%
df_TelecomX_Normalizado.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
#df_TelecomX_Normalizado['Charges.Total'].astype(str).str.strip().str.lower()
df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].astype(str)
df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total']\
    .str.replace('$', '', regex=False)\
    .str.replace(',', '', regex=False)\
    .str.strip()
df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].replace('', 0)
df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].astype(np.float64)
#df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].apply(lambda x: x.replace('$ ', '', regex=False).replace(' reais', '', regex=False).replace(',','.', regex=False).strip())
#df_TelecomX_Normalizado['Charges.Total'].apply(lambda x: x.replace('$ ', '', regex=False).replace(' reais', '', regex=False).replace(',','.', regex=False).strip())

# %%
df_TelecomX_Normalizado['Churn'] = df_TelecomX_Normalizado['Churn'].astype(str).str.strip().str.lower().replace('', 'no')

# %%
df_TelecomX_Normalizado['Churn'].dtype
#print(df_TelecomX_Normalizado['Churn'].dtype)
# Out:
# dtype('O')

# %%
print(df_TelecomX_Normalizado['Churn'].dtype)
# Out:
# object

# %%
df_TelecomX_Normalizado['Churn']
# Out:
# 0        no
# 1        no
# 2       yes
# 3       yes
# 4       yes
#        ...
# 7262     no
# 7263    yes
# 7264     no
# 7265     no
# 7266     no
# Name: Churn, Length: 7267, dtype: object

# %%
df_TelecomX_Normalizado['OnlineSecurity'].sample(5)
# Out:
# 5216                     no
# 1270    no internet service
# 4704                     no
# 3684    no internet service
# 516                     yes
# Name: OnlineSecurity, dtype: object

# %%
df_TelecomX_Normalizado['InternetService']
# Out:
# 0               dsl
# 1               dsl
# 2       fiber optic
# 3       fiber optic
# 4       fiber optic
#            ...
# 7262            dsl
# 7263    fiber optic
# 7264            dsl
# 7265            dsl
# 7266            dsl
# Name: InternetService, Length: 7267, dtype: object

# %%
#df_TelecomX_Normalizado['InternetService'] = df_TelecomX_Normalizado['InternetService'].astype(str).str.strip().str.lower()
#df_TelecomX_Normalizado['InternetService'].astype(str).str.strip().str.lower()

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 3638  5016-LIPDW    no    male              0     yes        yes      57
# 7002  9640-HXEAM    no    male              0      no         no       2
# 1532  2197-OMWGI    no  female              1     yes        yes      68
# 601   0856-NAOES    no    male              0      no         no       6
# 6961  9586-JGQKH    no  female              0     yes         no      64
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 3638          yes                no              no  ...  no internet service
# 7002           no  no phone service             dsl  ...                  yes
# 1532           no  no phone service             dsl  ...                  yes
# 601           yes                no             dsl  ...                   no
# 6961          yes               yes     fiber optic  ...                  yes
#
# ...

# %%
df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean()
# Out:
# InternetService
# dsl            58.009144
# fiber optic    91.514478
# no             21.082163
# Name: Charges.Monthly, dtype: float64

# %%
#df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].astype(np.float64)
#df_TelecomX_Normalizado['Charges.Total'].astype(np.float64)
#df_TelecomX_Normalizado['Charges.Total'].dtype
print(df_TelecomX_Normalizado['Charges.Total'].dtype)
# Out:
# float64

# %%
df_TelecomX_Normalizado['Charges.Total'].head(5)
# Out:
# 0     593.30
# 1     542.40
# 2     280.85
# 3    1237.85
# 4     267.40
# Name: Charges.Total, dtype: float64

# %%
df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Monthly']].mean().sort_values('Charges.Monthly')
# Out:
#                  Charges.Monthly
# InternetService
# no                     21.082163
# dsl                    58.009144
# fiber optic            91.514478

# %%
df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Total']].mean().sort_values('Charges.Total')
# Out:
#                  Charges.Total
# InternetService
# no                  664.137445
# dsl                2106.184124
# fiber optic        3207.659303

# %%
df_TelecomX_Normalizado.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total
# count    7267.000000  7267.000000      7267.000000    7267.000000
# mean        0.162653    32.346498        64.720098    2277.182035
# std         0.369074    24.571773        30.129572    2268.648587
# min         0.000000     0.000000        18.250000       0.000000
# 25%         0.000000     9.000000        35.425000     396.200000
# 50%         0.000000    29.000000        70.300000    1389.200000
# 75%         0.000000    55.000000        89.875000    3778.525000
# max         1.000000    72.000000       118.750000    8684.800000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['SeniorCitizen'].plot(kind='hist', bins=20, title='SeniorCitizen')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    no  female              0     yes        yes       9
# 1     0003-MKNFE    no    male              0      no         no       9
# 2     0004-TLHLJ   yes    male              0      no         no       4
# 3     0011-IGKFF   yes    male              1     yes         no      13
# 4     0013-EXCHZ   yes  female              1     yes         no       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    no  female              0      no         no      13
# 7263  9992-RRAMN   yes    male              0     yes         no      22
# 7264  9992-UJOEL    no    male              0      no         no       2
# 7265  9993-LHIEB    no    male              0     yes        yes      67
# 7266  9995-HOTOH    no    male              0     yes        yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
import numpy as np

# %%
df_TelecomX_Normalizado['Charges.Total']
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Charges.Total, Length: 7267, dtype: float64

# %% [markdown]
# ##🔧 ERRORES de Transformación

# %% [markdown]
# LAS SIGUIENTES LINEAS SON ERRORES DE INTENTOS PARA NORMALIZAR LAS 4 COLUMNAS DEL DATA FREME EXTRAIDO DEL ARCHIVO JSON

# %%
pd.merge(df_customer[['customerID', 'Churn']], df_customer_details, on='customerID')

# %%
pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path={'customer'}, meta=[{'customerID'}])

# %%
#Normalizando los datos anidados
df_customer = pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)
df_customer_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['customerID'])
df_phone_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='phone', meta=['customerID'])
df_internet_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='internet', meta=['customerID'])
df_account_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='account', meta=['customerID'])

# Uniendo los dataframes
df_normalized = pd.merge(df_customer[['customerID', 'Churn']], df_customer_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_phone_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_internet_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_account_details, on='customerID')

display(df_normalized.head())

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path=['customer'])

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path="customer", meta=["customerID", "Churn", ["phone", "internet", "account"]])

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['phone', 'internet', 'account'])

# %%
f_customer_details = pd.json_normalize(df_TelecomX_Data_Colab_2, record_path="customer", meta=["customerID"])

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta='customerID')

# %%
#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])

# %%
#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])

# %% [markdown]
# TERMINAN LOS ENSAYOS DE ERRORES DE NORMALIZACION

# %% [markdown]
# #📊 Carga y análisis

# %%
df_InternetService_Charges_Monthly = df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Monthly']].mean().sort_values ('Charges.Monthly')

# %%
df_InternetService_Charges_Monthly

# %%
df_InternetService_Charges_Monthly.plot(kind='barh',figsize=(12,8),color='purple')

# %%
df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Total']].mean().sort_values ('Charges.Total')

# %% [markdown]
# #📄Informe final
