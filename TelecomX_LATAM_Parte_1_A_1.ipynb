# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ##📌 LEYENDO json

# %%
import pandas as pd

# %%
# /content/TelecomX_Data.json
url_TelecomX_Data = 'https://github.com/lespmo/Challenge_Telecom_X_anAlisis_evasiOn_clientes/blob/d2cf422f1741ff3547e2c812955f21ea1ff12d85/TelecomX_Data.json'

# %%
df_TelecomX_Data_Colab = pd.read_json('/content/TelecomX_Data.json')
#df_TelecomX_Data_GiHub = pd.read_json('url_TelecomX_Data')

# %% [markdown]
# ##📌 REVISANDO LOS DATOS

# %%
df_TelecomX_Data_Colab
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df_TelecomX_Data_Colab.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_TelecomX_Data_Colab.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_TelecomX_Data_Colab.shape
# Out:
# (7267, 6)

# %%
df_TelecomX_Data_Colab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_TelecomX_Data_Colab.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_TelecomX_Data_Colab['customer']
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##🔧 IMPORTANDO BIBLIOTECAS

# %%
import json

# %%
import requests

# %% [markdown]
# ##🔧 NORMALIZANDO

# %%
pd.json_normalize(df_TelecomX_Data_Colab)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('TelecomX_Data.json','r') as f:
    df_TelecomX_Data_Colab_2 = json.loads(f.read())

# %%
 type(df_TelecomX_Data_Colab_2)
# Out:
# list

# %%
df_TelecomX_Data_Colab_2
# Out:
# [{'customerID': '0002-ORFBO',
#   'Churn': 'No',
#   'customer': {'gender': 'Female',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'No',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'No'},
#   'account': {'Contract': 'One year',
#    'PaperlessBilling': 'Yes',
#    'PaymentMethod': 'Mailed check',
#    'Charges': {'Monthly': 65.6, 'Total': '593.3'}}},
#  {'customerID': '0003-MKNFE',
#   'Churn': 'No',
#   'customer': {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'No',
#    'Dependents': 'No',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'No',
#    'DeviceProtection': 'No',
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=0)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
type(df_TelecomX_Data_Colab_2)
# Out:
# list

# %%
type(df_customer)
# Out:
# pandas.core.frame.DataFrame

# %%
# pd.json_normalize(datos_pacientes_2_metodo, record_path='Pacientes', meta=['Investigación', 'Año'])
pd.json_normalize(df_TelecomX_Data_Colab['customer'])
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
pd.json_normalize(df_TelecomX_Data_Colab['phone'])
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
pd.json_normalize(df_TelecomX_Data_Colab['internet'])
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab['account'])
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %% [markdown]
# ##🔧 CREANDO df DE CADA LISTA ANIDAD

# %%
#Normalizando los datos con los parámetros record_path y meta
df_customer = pd.json_normalize(df_TelecomX_Data_Colab_2, max_level=0)
#pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])

# %%
df_TelecomX_Data_Colab.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_customer_details = pd.json_normalize(df_TelecomX_Data_Colab['customer'])

# %%
df_phone_details = pd.json_normalize(df_TelecomX_Data_Colab['phone'])

# %%
df_internet_details = pd.json_normalize(df_TelecomX_Data_Colab['internet'])

# %%
df_account_details = pd.json_normalize(df_TelecomX_Data_Colab['account'])

# %% [markdown]
# ##🔧 UNIENDO LOS DATA FRAME

# %%
df_customer
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df_customer_details
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_TelecomX_Data_Colab[['customerID', 'Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %%
df_base = df_TelecomX_Data_Colab[['customerID', 'Churn']]

# %%
pd.merge(df_base, df_customer_details, left_index=True, right_index=True)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
# [7267 rows x 7 columns]

# %%
df_TelecomX_Normalizado = pd.merge(df_base, df_customer_details, left_index=True, right_index=True)

# %%
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
# [7267 rows x 7 columns]

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_phone_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines
# 0             Yes                No
# ...

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_internet_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# ...

# %%
df_TelecomX_Normalizado = pd.merge(df_TelecomX_Normalizado, df_account_details, left_index=True, right_index=True)
df_TelecomX_Normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_TelecomX_Normalizado.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado.shape
# Out:
# (7267, 21)

# %% [markdown]
# ##🔧 GURADANDO ARCHIV JSON

# %%
df_TelecomX_Normalizado.to_json('TelecomX_Normalizado.json')

# %% [markdown]
# ##🔧REVISANDO  DATOS

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_TelecomX_Normalizado.tail()
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 7262          Yes                No             DSL  ...           No
# 7263          Yes               Yes     Fiber optic  ...           No
# 7264          Yes                No             DSL  ...          Yes
# 7265          Yes                No             DSL  ...           No
# 7266           No  No phone service             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_TelecomX_Normalizado.shape
# Out:
# (7267, 21)

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
df_TelecomX_Normalizado.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly
# count    7267.000000  7267.000000      7267.000000
# mean        0.162653    32.346498        64.720098
# std         0.369074    24.571773        30.129572
# min         0.000000     0.000000        18.250000
# 25%         0.000000     9.000000        35.425000
# 50%         0.000000    29.000000        70.300000
# 75%         0.000000    55.000000        89.875000
# max         1.000000    72.000000       118.750000

# %%
df_TelecomX_Normalizado.groupby('InternetService').mean(numeric_only=True)
# Out:
#                  SeniorCitizen     tenure  Charges.Monthly
# InternetService
# DSL                   0.107315  32.701367        58.009144
# Fiber optic           0.268918  32.923390        91.514478
# No                    0.034788  30.621126        21.082163

# %%
df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean()
# Out:
# InternetService
# DSL            58.009144
# Fiber optic    91.514478
# No             21.082163
# Name: Charges.Monthly, dtype: float64

# %%
# df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean().sort_values('Charges.Monthly')

# %%
df_TelecomX_Normalizado.groupby('InternetService').sum(numeric_only=True)
# Out:
#                  SeniorCitizen  tenure  Charges.Monthly
# InternetService
# DSL                        267   81361        144326.75
# Fiber optic                860  105289        292663.30
# No                          55   48412         33330.90

# %%
df_TelecomX_Normalizado.groupby(['InternetService', 'gender'])[['Charges.Monthly']].sum()
# Out:
#                         Charges.Monthly
# InternetService gender
# DSL             Female         71445.45
#                 Male           72881.30
# Fiber optic     Female        146253.35
#                 Male          146409.95
# No              Female         16296.10
#                 Male           17034.80

# %%
df_TelecomX_Normalizado.groupby(['InternetService', 'gender'])[['Charges.Monthly']].mean()
# Out:
#                         Charges.Monthly
# InternetService gender
# DSL             Female        58.465998
#                 Male          57.568167
# Fiber optic     Female        91.522747
#                 Male          91.506219
# No              Female        21.108938
#                 Male          21.056613

# %%
df_TelecomX_Normalizado.InternetService.unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
InternetService_ = ['DSL', 'Fiber optic', 'No']
InternetService_
# Out:
# ['DSL', 'Fiber optic', 'No']

# %%
df_TelecomX_Normalizado.query('@InternetService_  in InternetService')
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %% [markdown]
# ##🔧 LIMPIANDO Y DANDO FORMATO A  DATOS

# %% [markdown]
# CAMBIANDO EL TITULO DE LAS COLUMNAS CON EL SEPARADOR DE .

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
# cambiar los nombres de las columnas que tienen como separador .
#df = df.rename(columns={'Edad': 'Años'})
df_TelecomX_Normalizado = df_TelecomX_Normalizado.rename(columns={'Charges_Monthly': 'Charges.Monthly'})

# %%
df_TelecomX_Normalizado = df_TelecomX_Normalizado.rename(columns={'Charges_Total': 'Charges.Total'})

# %%
df_TelecomX_Normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado.groupby('InternetService')['Charges.Monthly'].mean()
# Out:
# InternetService
# DSL            58.009144
# Fiber optic    91.514478
# No             21.082163
# Name: Charges.Monthly, dtype: float64

# %%
df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Monthly']].mean().sort_values('Charges.Monthly')
# Out:
#                  Charges.Monthly
# InternetService
# No                     21.082163
# DSL                    58.009144
# Fiber optic            91.514478

# %%
df_TelecomX_Normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_TelecomX_Normalizado

# %%
import numpy as np

# %%
df_TelecomX_Normalizado['Charges.Total']
# Out:
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4
#          ...
# 7262      742.9
# 7263     1873.7
# 7264      92.75
# 7265    4627.65
# 7266     3707.6
# Name: Charges.Total, Length: 7267, dtype: object

# %% [markdown]
# ##🔧 ERRORES de Transformación

# %%
df_TelecomX_Normalizado['Charges.Total'] = df_TelecomX_Normalizado['Charges.Total'].astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3096077192.py in <cell line: 0>()
# ----> 1 df_TelecomX_Normalizado['Charges.Total'].astype(np.float64)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %% [markdown]
# LAS SIGUIENTES LINEAS SON ERRORES DE INTENTOS PARA NORMALIZAR LAS 4 COLUMNAS DEL DATA FREME EXTRAIDO DEL ARCHIVO JSON

# %%
pd.merge(df_customer[['customerID', 'Churn']], df_customer_details, on='customerID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1397362481.py in <cell line: 0>()
# ----> 1 pd.merge(df_customer[['customerID', 'Churn']], df_customer_details, on='customerID')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2271197497.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     458
#     459     if record_path is None:
# --> 460         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     461             # naive normalization, this is idempotent for flat records
#     462             # and potentially will inflate the data considerably for
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     458
#     459     if record_path is None:
# --> 460         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path={'customer'}, meta=[{'customerID'}])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1411638810.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab, record_path={'customer'}, meta=[{'customerID'}])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     483
#     484     meta_vals: DefaultDict = defaultdict(list)
# --> 485     meta_keys = [sep.join(val) for val in _meta]
#     486
#     487     def _recursive_extract(data, path, seen_meta, level: int = 0) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in <listcomp>(.0)
#     483
#     484     meta_vals: DefaultDict = defaultdict(list)
# --> 485     meta_keys = [sep.join(val) for val in _meta]
#     486
# ...

# %%
#Normalizando los datos anidados
df_customer = pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)
df_customer_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['customerID'])
df_phone_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='phone', meta=['customerID'])
df_internet_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='internet', meta=['customerID'])
df_account_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='account', meta=['customerID'])

# Uniendo los dataframes
df_normalized = pd.merge(df_customer[['customerID', 'Churn']], df_customer_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_phone_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_internet_details, on='customerID')
df_normalized = pd.merge(df_normalized, df_account_details, on='customerID')

display(df_normalized.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2671256655.py in <cell line: 0>()
#       1 #Normalizando los datos anidados
# ----> 2 df_customer = pd.json_normalize(df_TelecomX_Data_Colab, max_level=0)
#       3 df_customer_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['customerID'])
#       4 df_phone_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='phone', meta=['customerID'])
#       5 df_internet_details = pd.json_normalize(df_TelecomX_Data_Colab, record_path='internet', meta=['customerID'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     458
#     459     if record_path is None:
# --> 460         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path=['customer'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2042360641.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab, record_path=['customer'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# --> 499                 recs = _pull_records(obj, path[0])
#     500                 recs = [
#     501                     nested_to_record(r, sep=sep, max_level=max_level)
#
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path="customer", meta=["customerID", "Churn", ["phone", "internet", "account"]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1898880787.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab, record_path="customer", meta=["customerID", "Churn", ["phone", "internet", "account"]])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# --> 499                 recs = _pull_records(obj, path[0])
#     500                 recs = [
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['phone', 'internet', 'account'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1756039000.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab, record_path='customer', meta=['phone', 'internet', 'account'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# --> 499                 recs = _pull_records(obj, path[0])
#     500                 recs = [
# ...

# %%
f_customer_details = pd.json_normalize(df_TelecomX_Data_Colab_2, record_path="customer", meta=["customerID"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-566472586.py in <cell line: 0>()
# ----> 1 f_customer_details = pd.json_normalize(df_TelecomX_Data_Colab_2, record_path="customer", meta=["customerID"])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# --> 499                 recs = _pull_records(obj, path[0])
#     500                 recs = [
# ...

# %%
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta='customerID')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-543545410.py in <cell line: 0>()
# ----> 1 pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta='customerID')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# --> 499                 recs = _pull_records(obj, path[0])
#     500                 recs = [
# ...

# %%
#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-700707902.py in <cell line: 0>()
#       1 #Normalizando los datos con los parámetros record_path y meta
# ----> 2 pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', 'phone', 'internet', 'account'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# ...

# %%
#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-171761143.py in <cell line: 0>()
#       1 #Normalizando los datos con los parámetros record_path y meta
# ----> 2 pd.json_normalize(df_TelecomX_Data_Colab_2, record_path='customer', meta=['customerID', 'Churn', ['phone', 'internet', 'account']])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 records.extend(recs)
#     516
# --> 517     _recursive_extract(data, record_path, {}, level=0)
#     518
#     519     result = DataFrame(records)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     497         else:
#     498             for obj in data:
# ...

# %% [markdown]
# TERMINAN LOS ENSAYOS DE ERRORES DE NORMALIZACION

# %% [markdown]
# #📊 Carga y análisis

# %%
df_InternetService_Charges_Monthly = df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Monthly']].mean().sort_values ('Charges.Monthly')

# %%
df_InternetService_Charges_Monthly
# Out:
#                  Charges.Monthly
# InternetService
# No                     21.082163
# DSL                    58.009144
# Fiber optic            91.514478

# %%
df_InternetService_Charges_Monthly.plot(kind='barh',figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='InternetService'>

# %%
df_TelecomX_Normalizado.groupby('InternetService')[['Charges.Total']].mean().sort_values ('Charges.Total')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %% [markdown]
# #📄Informe final
